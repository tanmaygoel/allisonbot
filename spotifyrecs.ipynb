# %%
import pandas

# %%
df = pandas.read_excel('SpotifyFeatures.xlsx')

df.head()
# Out:
#    genre      artist_name                                         track_name  \
# 0  Opera   Giuseppe Verdi  Stiffelio, Act III: Ei fugge! … Lina, pensai c...
# 1  Opera  Giacomo Puccini  Madama Butterfly / Act 1: ... E soffitto e pareti
# 2  Opera  Giacomo Puccini      Turandot / Act 2: Gloria, gloria, o vincitore
# 3  Opera   Giuseppe Verdi       Rigoletto, Act IV: Venti scudi hai tu detto?
# 4  Opera   Giuseppe Verdi           Don Carlo / Act 4: "Ella giammai m'amò!"
#
#                  track_id  popularity  acousticness  danceability  \
# 0  7EsKYeHtTc4H4xWiTqSVZA          21         0.986         0.313
# 1  7MfmRBvqaW0I6UTxXnad8p          18         0.972         0.360
# 2  7pBo1GDhIysyUMFXiDVoON          10         0.935         0.168
# 3  02mvYZX5aKNzdqEo6jF20m          17         0.961         0.250
# 4  03TW0jwGMGhUabAjOpB1T9          19         0.985         0.142
#
#    duration_ms   energy  instrumentalness key  liveness  loudness   mode  \
# ...

# %%
fav_artist = 'queen'.title()

fav_artist
# Out:
# 'Queen'

# %%
row = df.loc[df['artist_name'] == fav_artist]

genre = row['genre']

genre
# Out:
# 165224    Rock
# 165225    Rock
# 165233    Rock
# 165235    Rock
# 165236    Rock
# 165252    Rock
# 165269    Rock
# 165292    Rock
# 165302    Rock
# 165336    Rock
# 165360    Rock
# 165381    Rock
# 165420    Rock
# 165437    Rock
# 165518    Rock
# 165542    Rock
# 165546    Rock
# 165547    Rock
# 165597    Rock
# 165654    Rock
# 165675    Rock
# 165678    Rock
# 165797    Rock
# 165826    Rock
# 165834    Rock
# 165962    Rock
# 166063    Rock
# 166088    Rock
# 166122    Rock
# 166138    Rock
#           ...
# 213008    Rock
# 213086    Rock
# 213173    Rock
# 213361    Rock
# 213714    Rock
# 214088    Rock
# 214146    Rock
# 214210    Rock
# 214389    Rock
# 214418    Rock
# 214472    Rock
# 214484    Rock
# 214695    Rock
# 214768    Rock
# 214968    Rock
# 215158    Rock
# 215277    Rock
# 215370    Rock
# 215666    Rock
# 216004    Rock
# 216116    Rock
# 217188    Rock
# 217207    Rock
# 217231    Rock
# 217420    Rock
# 218110    Rock
# 218246    Rock
# ...
